# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

#Constants
HTTP_STATUS_OK = 200
HTTP_STATUS_NOT_FOUND = 404

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=9000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=9000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 2149

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=baff5a87b13d75787c97e4f30f1f06c4

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Starting Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
not_found_count = 0

# Loop through the cities in the list and pull data from 2000.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 
#Run an API request for each of the cities.
    #get a response for each lat-lgn pair.
    response = requests.get(city_url)
    response_status = response.status_code
    if response_status == HTTP_STATUS_OK:
        # Parse out the needed data.
        city_weather = response.json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    #if there is not data for that city available, skip.
    elif response_status == HTTP_STATUS_NOT_FOUND:
        print(f"City {city} not found. Skipping...")
        not_found_count += 1
    #if there is another unexpected error, raise the error.
    else:
        raise ValueError(f"HTTP status {response_status} for city {city}")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Starting Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | viligili
# City viligili not found. Skipping...
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | changji
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | broome
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | raha
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | ilulissat
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
#Check that the df has columns in the correct order.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Thompson      CA  55.7435  -97.8558    -20.04        69          75
# 1        Airai      TL  -8.9266  125.4092     72.25        72          91
# 2  Provideniya      RU  64.3833 -173.3000    -15.38        90           4
# 3      Changji      CN  44.0167   87.3167     14.79        92          75
# 4       Atuona      PF  -9.8000 -139.0333     78.08        75           8
#
#    Wind Speed Current Description
# 0        4.61       broken clouds
# 1        1.63     overcast clouds
# 2        8.68           clear sky
# 3        2.24                mist
# 4       12.77           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
